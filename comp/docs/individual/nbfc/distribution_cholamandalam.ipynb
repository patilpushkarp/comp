# %% [markdown]
# # Cholamandalam

# %%
# Load necessary libraries
import sys
import glob
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import gensim
import spacy
import numpy as np
import tqdm.notebook as tqdm
from tqdm.auto import tqdm
tqdm.pandas()
from pprint import pprint
import pickle
import plotly.express as px
import pyLDAvis

sys.path.append('/Users/pushkar/Documents/projects/fin_comp/comp/docs')

import utils.helper
from utils.helper import Processor
import importlib
importlib.reload(utils.helper)
# Out:
# <module 'utils.helper' from '/Users/pushkar/Documents/projects/fin_comp/comp/docs/utils/helper.py'>

# %%
# Load data
df = pd.read_csv('./../../data/nbfc/cholamandalam/cholamandalam.csv')

# %%
# Know the shape of the loaded data
df.shape
# Out:
# (2603, 27)

# %% [markdown]
# Perform lemmatization, word correction

# %%
words = ["harassment", "fraud", "restructure", "covid19 relief", "force", "money cut", "unethical", "fake", "false promise", "shutdown",
         "moratorium", "no response", "scam", "no answer", "love", "responsive", "very bad", "machine learning", "algorithm", "delay", 
         "leveraging"]

# %%
processor = Processor('./../../data/config.json')

# %%
pre_df = df[df['date'] < '2020-02-01']
post_df = df[df['date'] >= '2020-02-01']

# %%
pre_result = processor.words_distribution(pre_df, words)
# Out:
# 100%|██████████| 1217/1217 [00:03<00:00, 351.69it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 431.13it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 433.77it/s]
# 100%|██████████| 1217/1217 [00:03<00:00, 392.53it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 410.54it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 445.01it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 446.54it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 441.84it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 447.46it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 454.94it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 448.23it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 417.57it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 438.93it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 439.06it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 451.60it/s]
# 100%|██████████| 1217/1217 [00:03<00:00, 371.48it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 440.83it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 443.45it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 447.48it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 453.67it/s]
# 100%|██████████| 1217/1217 [00:02<00:00, 437.41it/s]
# 100%|██████████| 21/21 [00:59<00:00,  2.84s/it]

# %%
pre_result.to_csv('./../../data/nbfc/cholamandalam/pre_wd.csv', index=False)

# %%
post_result = processor.words_distribution(post_df, words)
# Out:
# 100%|██████████| 1386/1386 [00:03<00:00, 368.19it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 408.15it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 414.52it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 408.52it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 403.99it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 382.17it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 397.92it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 410.11it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 405.50it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 408.88it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 417.12it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 415.73it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 415.53it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 411.42it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 413.22it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 415.74it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 397.10it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 413.66it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 411.11it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 415.80it/s]
# 100%|██████████| 1386/1386 [00:03<00:00, 420.51it/s]
# 100%|██████████| 21/21 [01:11<00:00,  3.41s/it]

# %%
post_result.to_csv('./../../data/nbfc/cholamandalam/post_wd.csv', index=False)

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))

sns.barplot(x='true_percent', y='words', data=pre_result, orient='h', ax=axes[0])

sns.barplot(x='true_percent', y='words', data=post_result, orient='h', ax=axes[1])
# Out:
# <AxesSubplot: xlabel='true_percent', ylabel='words'>

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))

sns.barplot(x='true_cnt', y='words', data=pre_result, orient='h', ax=axes[0])

sns.barplot(x='true_cnt', y='words', data=post_result, orient='h', ax=axes[1])
# Out:
# <AxesSubplot: xlabel='true_cnt', ylabel='words'>
