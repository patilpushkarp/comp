# %% [markdown]
# # Pine Labs

# %%
# Load necessary libraries
import sys
import glob
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import gensim
import spacy
import numpy as np
import tqdm.notebook as tqdm
from tqdm.auto import tqdm
tqdm.pandas()
from pprint import pprint
import pickle
import plotly.express as px
import pyLDAvis

sys.path.append('/Users/pushkar/Documents/projects/fin_comp/comp/docs')

import utils.helper
from utils.helper import Processor
import importlib
importlib.reload(utils.helper)
# Out:
# <module 'utils.helper' from '/Users/pushkar/Documents/projects/fin_comp/comp/docs/utils/helper.py'>

# %%
# Load data
df = pd.read_csv('./../../data/fintech/pine_labs/pine_labs.csv')

# %%
# Know the shape of the loaded data
df.shape
# Out:
# (10483, 27)

# %% [markdown]
# Perform lemmatization, word correction

# %%
words = ["harassment", "fraud", "restructure", "covid19 relief", "force", "money cut", "unethical", "fake", "false promise", "shutdown",
         "moratorium", "no response", "scam", "no answer", "love", "responsive", "very bad", "machine learning", "algorithm", "delay", 
         "leveraging"]

# %%
processor = Processor('./../../data/config.json')

# %%
pre_df = df[df['date'] < '2020-02-01']
post_df = df[df['date'] >= '2020-02-01']

# %%
pre_result = processor.words_distribution(pre_df, words)
# Out:
# 100%|██████████| 3435/3435 [00:08<00:00, 413.66it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 453.64it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 449.30it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 448.97it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 438.62it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 447.37it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 444.93it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 448.35it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 438.76it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 440.78it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 442.60it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 443.22it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 435.67it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 439.41it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 440.53it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 434.48it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 439.18it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 439.69it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 434.67it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 438.38it/s]
# 100%|██████████| 3435/3435 [00:07<00:00, 431.79it/s]
# 100%|██████████| 21/21 [02:44<00:00,  7.81s/it]

# %%
pre_result.to_csv('./../../data/fintech/pine_labs/pre_wd.csv', index=False)

# %%
post_result = processor.words_distribution(post_df, words)
# Out:
# 100%|██████████| 7048/7048 [00:17<00:00, 400.57it/s]
# 100%|██████████| 7048/7048 [00:16<00:00, 417.44it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 413.10it/s]
# 100%|██████████| 7048/7048 [00:16<00:00, 417.72it/s]
# 100%|██████████| 7048/7048 [00:16<00:00, 415.64it/s]
# 100%|██████████| 7048/7048 [00:16<00:00, 415.35it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 409.58it/s]
# 100%|██████████| 7048/7048 [00:19<00:00, 355.41it/s]
# 100%|██████████| 7048/7048 [00:20<00:00, 347.70it/s]
# 100%|██████████| 7048/7048 [00:20<00:00, 336.94it/s]
# 100%|██████████| 7048/7048 [00:20<00:00, 345.93it/s]
# 100%|██████████| 7048/7048 [00:20<00:00, 352.11it/s]
# 100%|██████████| 7048/7048 [00:19<00:00, 354.34it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 397.65it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 398.95it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 406.85it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 404.29it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 399.23it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 407.98it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 405.76it/s]
# 100%|██████████| 7048/7048 [00:17<00:00, 409.59it/s]
# 100%|██████████| 21/21 [06:20<00:00, 18.12s/it]

# %%
post_result.to_csv('./../../data/fintech/pine_labs/post_wd.csv', index=False)

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))

sns.barplot(x='true_percent', y='words', data=pre_result, orient='h', ax=axes[0])

sns.barplot(x='true_percent', y='words', data=post_result, orient='h', ax=axes[1])
# Out:
# <AxesSubplot: xlabel='true_percent', ylabel='words'>

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 10))

sns.barplot(x='true_cnt', y='words', data=pre_result, orient='h', ax=axes[0])

sns.barplot(x='true_cnt', y='words', data=post_result, orient='h', ax=axes[1])
# Out:
# <AxesSubplot: xlabel='true_cnt', ylabel='words'>
